# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import silhouette_score 
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('test.csv')

# %%
data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
data.shape
# Out:
# (2947, 563)

# %%
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
data = data.dropna()
data = data.drop_duplicates()

# %%
data.describe().style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e882">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e882_level0_col0" class="col_heading level0 col0" >tBodyAcc-mean()-X</th>
#       <th id="T_6e882_level0_col1" class="col_heading level0 col1" >tBodyAcc-mean()-Y</th>
#       <th id="T_6e882_level0_col2" class="col_heading level0 col2" >tBodyAcc-mean()-Z</th>
#       <th id="T_6e882_level0_col3" class="col_heading level0 col3" >tBodyAcc-std()-X</th>
#       <th id="T_6e882_level0_col4" class="col_heading level0 col4" >tBodyAcc-std()-Y</th>
#       <th id="T_6e882_level0_col5" class="col_heading level0 col5" >tBodyAcc-std()-Z</th>
#       <th id="T_6e882_level0_col6" class="col_heading level0 col6" >tBodyAcc-mad()-X</th>
#       <th id="T_6e882_level0_col7" class="col_heading level0 col7" >tBodyAcc-mad()-Y</th>
#       <th id="T_6e882_level0_col8" class="col_heading level0 col8" >tBodyAcc-mad()-Z</th>
# ...

# %%
Labels = data['Activity']

data = data.drop(columns=['Activity'])

# %% [markdown]
# Normalization of data features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(data)

# %% [markdown]
# To determine the optimal number of clusters based on the distance of each data point to the nearest cluster center

# %%
num_clusters = [i for i in range(2, 11)]

def kmeans_inertia(num_clusters, x_vals):
    inertia = []
    for num in num_clusters:
        kms = KMeans(n_clusters=num)
        kms.fit(x_vals)
        inertia.append(kms.inertia_)
    return inertia

inertia = kmeans_inertia(num_clusters, X_scaled)

plot = sns.lineplot(x=num_clusters, y=inertia)
plot.set_xlabel("Number of clusters")
plot.set_ylabel("Inertia")
plt.show()

# %% [markdown]
# How close is each data point to the centroid of its own cluster, and how far is it from the centroids of other clusters?

# %%
def kmeans_sil(num_clusters, x_vals):
    
  
    sil_score = []
    for num in num_clusters:
        kms = KMeans(n_clusters=num)
        kms.fit(x_vals)
        sil_score.append(silhouette_score(x_vals, kms.labels_))
    
    return sil_score

sil_score = kmeans_sil(num_clusters, X_scaled)
sil_score
# Out:
# [0.3913060431047856,
#  0.3036629820782968,
#  0.26416268323669406,
#  0.12737847511248854,
#  0.10276724791418672,
#  0.09788266505450863,
#  0.09675076453685073,
#  0.08998375518982943,
#  0.0761618390568354]

# %%
plot = sns.lineplot(x=num_clusters, y=sil_score)
plot.set_xlabel("# of clusters");
plot.set_ylabel("Silhouette Score");

# %%
k_means = KMeans(n_clusters=3)
k_means.fit(X_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
print('Clusters: ', k_means.labels_)
print('Inertia: ', k_means.inertia_)
# Out:
# Clusters:  [2 2 2 ... 1 1 1]
# Inertia:  817247.6501792278

# %% [markdown]
# Calculate the mean of features for each cluster after applying clustering

# %%
clusters_mean = pd.DataFrame(X_scaled).groupby(k_means.labels_).mean()
clusters_mean
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.123534 -0.028279 -0.025079  1.371515  1.303630  1.152679  1.373857
# 1 -0.111185 -0.091441 -0.046200  0.722301  0.755042  0.848359  0.716571
# 2  0.016716  0.060174  0.034260 -0.885738 -0.879398 -0.876530 -0.883438
#
#         7         8         9    ...       552       553       554       555  \
# 0  1.282631  1.128485  1.349182  ...  0.451275  0.385508 -0.089458  0.029556
# 1  0.766134  0.865335  0.717522  ...  0.079940  0.091309  0.050041 -0.023876
# 2 -0.877964 -0.877176 -0.875139  ... -0.205084 -0.187799  0.004581  0.002507
#
#         556       557       558       559       560       561
# 0  0.093217 -0.056495 -0.458250  0.472043  0.423959 -0.052168
# 1 -0.002671 -0.008578 -0.407938  0.472247  0.499056 -0.048332
# 2 -0.031860  0.024892  0.387159 -0.427300 -0.424790  0.045110
#
# [3 rows x 562 columns]

# %% [markdown]
# Which labels are included in each cluster

# %%
df = pd.DataFrame({'clust_label': k_means.labels_, 'orig_label': Labels.tolist()})

ct = pd.crosstab(df['clust_label'], df['orig_label'])
ct
# Out:
# orig_label   LAYING  SITTING  STANDING  WALKING  WALKING_DOWNSTAIRS  \
# clust_label
# 0                 0        0         0      212                 282
# 1                 4        6         3      284                 138
# 2               533      485       529        0                   0
#
# orig_label   WALKING_UPSTAIRS
# clust_label
# 0                          59
# 1                         412
# 2                           0

# %% [markdown]
#  clustering visualization

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=k_means.labels_, palette="Set2")
plt.title('KMeans Clustering with PCA Reduction')
plt.show()
